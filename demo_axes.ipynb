# %%
import numpy as np

# %%
m23 = np.array([[1,2,3],[4,5,6]])
m23
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
print(np.sum(m23))
# Out:
# 21

# %%
print(np.sum(m23, axis=0))
# Out:
# [5 7 9]

# %%
print(np.sum(m23, axis=1))
# Out:
# [ 6 15]

# %%
m23[:,1:]
# Out:
# array([[2, 3],
#        [5, 6]])
