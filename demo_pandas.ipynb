# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
print(pd.__version__)
# Out:
# 3.0.5

# %%
df = pd.read_csv("data/house/house.csv", delimiter=",")
df
# Out:
#      loyer  surface
# 0     1330       37
# 1     1400       32
# 2      904       26
# 3      955       30
# 4     2545       70
# ..     ...      ...
# 540   1490       48
# 541   2020       58
# 542   2050       70
# 543   1220       42
# 544   1610       44
#
# [545 rows x 2 columns]

# %%
df["loyer_m2"] = df["loyer"] / df["surface"]
df
# Out:
#      loyer  surface   loyer_m2
# 0     1330       37  35.945946
# 1     1400       32  43.750000
# 2      904       26  34.769231
# 3      955       30  31.833333
# 4     2545       70  36.357143
# ..     ...      ...        ...
# 540   1490       48  31.041667
# 541   2020       58  34.827586
# 542   2050       70  29.285714
# 543   1220       42  29.047619
# 544   1610       44  36.590909
#
# [545 rows x 3 columns]

# %%
plt.scatter(df["surface"], df["loyer"])
plt.show()

# %%
df.to_html("data/house/house.html")
df.to_json("data/house/house.json")
df.to_excel("data/house/house.xlsx", index=False)
my_json = df.to_json()

# %%
np.mean(df["surface"])
# Out:
# np.float64(63.236697247706424)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'loyer'}>,
#         <Axes: title={'center': 'surface'}>],
#        [<Axes: title={'center': 'loyer_m2'}>, <Axes: >]], dtype=object)
