# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/absenteeism_at_work/absence_cat.csv", delimiter=",")
df.head(10)
# Out:
#    Unnamed: 0  id  reason_for_absence  month_of_absence  day_of_the_week  \
# 0           0  11                  26                 7                3
# 1           1  36                   0                 7                3
# 2           2   3                  23                 7                4
# 3           3   7                   7                 7                5
# 4           4  11                  23                 7                5
# 5           5   3                  23                 7                6
# 6           6  10                  22                 7                6
# 7           7  20                  23                 7                6
# 8           8  14                  19                 7                2
# 9           9   1                  22                 7                2
#
#    seasons  transportation_expense  distance_from_residence_to_work  \
# 0        1                     289                               36
# 1        1                     118                               13
# 2        1                     179                               51
# 3        1                     279                                5
# 4        1                     289                               36
# 5        1                     179                               51
# 6        1                     361                               52
# 7        1                     260                               50
# 8        1                     155                               12
# 9        1                     235                               11
#
#    service_time  age  ...  education  son  social_drinker  social_smoker  pet  \
# 0            13   33  ...          1    2               1              0    1
# 1            18   50  ...          1    1               1              0    0
# 2            18   38  ...          1    0               1              0    0
# 3            14   39  ...          1    2               1              1    0
# 4            13   33  ...          1    2               1              0    1
# 5            18   38  ...          1    0               1              0    0
# 6             3   28  ...          1    1               1              0    4
# 7            11   36  ...          1    4               1              0    0
# 8            14   34  ...          1    2               1              0    0
# 9            14   37  ...          3    1               0              0    1
#
#    weight  height  body_mass_index  absenteeism_time_in_hours  \
# 0      90     172               30                          4
# 1      98     178               31                          0
# 2      89     170               31                          2
# 3      68     168               24                          4
# 4      90     172               30                          2
# 5      89     170               31                          2
# 6      80     172               27                          8
# 7      65     168               23                          4
# 8      95     196               25                         40
# 9      88     172               29                          8
#
#    absence_category
# 0                 1
# 1                 0
# 2                 1
# 3                 1
# 4                 1
# 5                 1
# 6                 2
# 7                 1
# 8                 4
# 9                 2
#
# [10 rows x 23 columns]

# %%
y = df["absence_category"]
x = df.drop(["absence_category", "absenteeism_time_in_hours", "id"], axis=1)

# %%
# Train test split
# modèle knn avec k = 3
# score
# tester toutes les valeurs de k entre 3 et 15
